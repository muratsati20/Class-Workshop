# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">EXERCISE</p>
#
# <a id="13"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
weather = pd.read_csv("weatherAUS.csv")
weather.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
weather.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
weather['Date'] = pd.to_datetime(weather['Date'])
weather['Date']
# Out:
# 0        2008-12-01
# 1        2008-12-02
# 2        2008-12-03
# 3        2008-12-04
# 4        2008-12-05
#             ...
# 145455   2017-06-21
# 145456   2017-06-22
# 145457   2017-06-23
# 145458   2017-06-24
# 145459   2017-06-25
# Name: Date, Length: 145460, dtype: datetime64[ns]

# %%
weather["year_month"] = weather['Date'].dt.strftime("%Y-%m")
weather["year"] = weather['Date'].dt.year
weather["month"] = weather['Date'].dt.month

# %%
weather.head(1)
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure3pm  Cloud9am  Cloud3pm  \
# 0           W           44.0          W  ...      1007.1       8.0       NaN
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  year_month  year  month
# 0     16.9     21.8         No            No     2008-12  2008     12
#
# [1 rows x 26 columns]

# %%
# pop() method works for a single column and returns a Series

year_month = weather.pop("year_month")
year = weather.pop("year")
month = weather.pop("month")

# Let's insert the columns we have popp

weather.insert(1, "year_month", year_month)
weather.insert(2, "year", year)
weather.insert(3, "month", month)

weather.head()
# Out:
#         Date year_month  year  month Location  MinTemp  MaxTemp  Rainfall  \
# 0 2008-12-01    2008-12  2008     12   Albury     13.4     22.9       0.6
# 1 2008-12-02    2008-12  2008     12   Albury      7.4     25.1       0.0
# 2 2008-12-03    2008-12  2008     12   Albury     12.9     25.7       0.0
# 3 2008-12-04    2008-12  2008     12   Albury      9.2     28.0       0.0
# 4 2008-12-05    2008-12  2008     12   Albury     17.5     32.3       1.0
#
#    Evaporation  Sunshine  ... Humidity9am  Humidity3pm Pressure9am  \
# 0          NaN       NaN  ...        71.0         22.0      1007.7
# 1          NaN       NaN  ...        44.0         25.0      1010.6
# 2          NaN       NaN  ...        38.0         30.0      1007.6
# 3          NaN       NaN  ...        45.0         16.0      1017.6
# 4          NaN       NaN  ...        82.0         33.0      1010.8
#
#   Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# ...

# %%
weather = weather[weather["year"]==2016]

# %%
weather.head()
# Out:
#            Date year_month  year  month Location  MinTemp  MaxTemp  Rainfall  \
# 2498 2016-01-01    2016-01  2016      1   Albury     20.4     37.6       0.0
# 2499 2016-01-02    2016-01  2016      1   Albury     20.9     33.6       0.4
# 2500 2016-01-03    2016-01  2016      1   Albury     18.4     23.1       2.2
# 2501 2016-01-04    2016-01  2016      1   Albury     17.3     23.7      15.6
# 2502 2016-01-05    2016-01  2016      1   Albury     15.5     22.9       6.8
#
#       Evaporation  Sunshine  ... Humidity9am  Humidity3pm Pressure9am  \
# 2498          NaN       NaN  ...        46.0         17.0      1013.4
# 2499          NaN       NaN  ...        54.0         30.0      1011.1
# 2500          NaN       NaN  ...        62.0         67.0      1014.0
# 2501          NaN       NaN  ...        74.0         65.0      1017.9
# 2502          NaN       NaN  ...        92.0         63.0      1016.3
#
#      Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather.shape
# Out:
# (17934, 26)

# %%
weather["Location"].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
albury_weather = weather[weather["Location"]=="Albury"]
portland_weather = weather[weather["Location"]=="Portland"]

# %%
albury_weather.head(1)
# Out:
#            Date year_month  year  month Location  MinTemp  MaxTemp  Rainfall  \
# 2498 2016-01-01    2016-01  2016      1   Albury     20.4     37.6       0.0
#
#       Evaporation  Sunshine  ... Humidity9am  Humidity3pm Pressure9am  \
# 2498          NaN       NaN  ...        46.0         17.0      1013.4
#
#      Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 2498      1009.2       7.0       3.0     26.1     36.7         No
#
#       RainTomorrow
# 2498            No
#
# [1 rows x 26 columns]

# %%
portland_weather.head(1)
# Out:
#             Date year_month  year  month  Location  MinTemp  MaxTemp  \
# 77447 2016-01-01    2016-01  2016      1  Portland     15.8     21.3
#
#        Rainfall  Evaporation  Sunshine  ... Humidity9am  Humidity3pm  \
# 77447       0.0         12.8       3.6  ...        80.0         71.0
#
#       Pressure9am Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 77447      1015.8      1016.4       8.0       8.0     17.7     18.2
#
#        RainToday  RainTomorrow
# 77447         No            No
#
# [1 rows x 26 columns]

# %% [markdown]
# **Instructions**
# - Import the matplotlib.pyplot API, using the conventional name plt.
# - Create an empty plot with functional method.
# - Show the results using the plt.show function.

# %%
# CODE HERE to get below output

import matplotlib.pyplot as plt

plt.plot()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
# - Import the matplotlib.pyplot API, using the conventional name plt.
# - Create an empty plot with object oriented method.
# - Show the results using the plt.show function.

# %%
# CODE HERE to get below output

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
# - Create a multiple-line in the same graph with functional method.
# - Plot MaxTemp from albury_weather against the month.
# - Plot MinTemp from albury_weather against the month.
# - Show the results using the plt.show function.

# %%
# CODE HERE to get below output

plt.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").MaxTemp.mean())
plt.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").MinTemp.mean())

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
# - Create a multiple-line in the same graph with object oriented method.
# - Plot MaxTemp from portland_weather against the month.
# - Plot MinTemp from portland_weather against the month.
# - Show the results using the plt.show function.

# %%
# CODE HERE to get below output

fig, ax = plt.subplots()

ax.plot(portland_weather.month.unique(),
         portland_weather.groupby("month").MaxTemp.mean())
ax.plot(portland_weather.month.unique(),
         portland_weather.groupby("month").MinTemp.mean())

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
#
# - Create a multiple-line in the same graph with functional method.
# - Plot MaxTemp from albury_weather against the month.
# - Plot MaxTemp from portland_weather against the month.
# - Set the x-axis label to 'Month'.
# - Set the y-axis label to 'Maximum Temperature'
# - Set title to 'Albury vs Portland Weather'-
# - Pass the ``color`` key-word arguments to these commands to set the color of the Albury data to blue ('b') and the Portland data to red ('r').
# - Pass the ``marker`` key-word arguments to these commands to set the Albury data to circle markers ('o') and the Portland markers to triangles pointing downwards ('v').
# - Pass the ``linestyle`` key-word argument to use dashed lines for the data from both cities ('--').

# %%
# CODE HERE to get below output

plt.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").MaxTemp.mean(),
         color="b",
         marker="o")
plt.plot(portland_weather.month.unique(),
         portland_weather.groupby("month").MaxTemp.mean(),
         color="r",
         marker="v")

plt.title("Albury vs Portland Weather")
plt.xlabel("Month")
plt.ylabel("Maximum Temperature")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
#
# - Create a multiple-line in the same graph with object oriented method.
# - Plot MinTemp from albury_weather against the month.
# - Plot MinTemp from portland_weather against the month.
# - Set the x-axis label to 'Month'.
# - Set the y-axis label to 'Minimum Temperature'
# - Set title to 'Albury vs Portland Weather'-
# - Pass the ``color`` key-word arguments to these commands to set the color of the Albury data to green ('g') and the Portland data to yellow ('y').
# - Pass the ``marker`` key-word arguments to these commands to set the Albury data to x markers ('x') and the Portland markers to triangles pointing upwards ('^').
# - Pass the ``linestyle`` key-word argument to use solid line for the data from both cities ('-').

# %%
# CODE HERE to get below output

fig, ax = plt.subplots()

ax.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").MinTemp.mean(),
         color="g",
         marker="x")
ax.plot(portland_weather.month.unique(),
         portland_weather.groupby("month").MinTemp.mean(),
         color="y",
         marker="^")

ax.set_title("Albury vs Portland Weather")
ax.set_xlabel("Month")
ax.set_ylabel("Maximum Temperature")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
#
# - Create a subplots with 2 rows and 2 columns with functional method.
# - Addressing the top left as index (2, 2, 1) plot the Albury WindSpeed9am.
# - Addressing the top right as index (2, 2, 2) plot the Portland WindSpeed9am.
# - Addressing the bottom left as index (2, 2, 3) plot the Albury WindSpeed3pm.
# - Addressing the bottom right as index (2, 2, 4) plot the Portland WindSpeed3pm.

# %%
# CODE HERE to get below output

plt.subplot(2,2,1)
plt.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").WindSpeed9am.mean())
plt.title("Albury")
plt.ylabel("WindSpeed9am")

plt.subplot(2,2,2)
plt.plot(portland_weather.month.unique(),
         portland_weather.groupby("month").WindSpeed9am.mean())
plt.title("Portland")

plt.subplot(2,2,3)
plt.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").WindSpeed3pm.mean())
plt.ylabel("WindSpeed3pm")

plt.subplot(2,2,4)
plt.plot(portland_weather.month.unique(),
         portland_weather.groupby("month").WindSpeed3pm.mean())

plt.tight_layout()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
#
# - Create a subplots with 2 rows and 2 columns with object oriented method.
# - Addressing the top left as index (2, 2, 1) plot the Albury Humidity9am.
# - Addressing the top right as index (2, 2, 2) plot the Portland Humidity9am.
# - Addressing the bottom left as index (2, 2, 3) plot the Albury Humidity3pm.
# - Addressing the bottom right as index (2, 2, 4) plot the Portland Humidity3pm.

# %%
# CODE HERE to get below output

fig, ax = plt.subplots(nrows = 2, ncols = 2)

ax[0,0].plot(albury_weather.month.unique(),
             albury_weather.groupby("month").WindSpeed9am.mean())
ax[0,0].set_title("Albury")
ax[0,0].set_ylabel("WindSpeed9am")

ax[0,1].plot(portland_weather.month.unique(),
             portland_weather.groupby("month").WindSpeed9am.mean())
ax[0,1].set_title("Portland")

ax[1,0].plot(albury_weather.month.unique(),
             albury_weather.groupby("month").WindSpeed3pm.mean())
ax[1,0].set_ylabel("WindSpeed3pm")

ax[1,1].plot(portland_weather.month.unique(),
             portland_weather.groupby("month").WindSpeed3pm.mean())

plt.tight_layout()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Instructions**
#
# - Create a figure and add axes as shown below with fig.add_axes().

# %%
# CODE HERE to get below output

fig = plt.figure()

ax1 = fig.add_axes([0.0, 0.0, 0.75, 1.35]) # left, bottom, width, height (range 0 to 1)
ax1.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").MinTemp.mean())
ax1.set_xlabel("Month")
ax1.set_ylabel("Minimum Temperature")

ax2 = fig.add_axes([0.9, 0.0, 0.35, 0.3])
ax2.plot(albury_weather.month.unique(),
         albury_weather.groupby("month").WindSpeed9am.mean())
ax2.set_xlabel("Month")
ax2.set_ylabel("WindSpeed9am")

ax3 = fig.add_axes([0.9, 0.35, 0.35, 0.3])
ax3.plot(albury_weather.month.unique(),
             albury_weather.groupby("month").Humidity9am.mean())
ax3.set_ylabel("Humidity9am")

ax4 = fig.add_axes([0.9, 0.70, 0.35, 0.3])
ax4.plot(albury_weather.month.unique(),
             albury_weather.groupby("month").Pressure9am.mean())
ax4.set_ylabel("Pressure9am")

ax5 = fig.add_axes([0.9, 1.05, 0.35, 0.3])
ax5.plot(albury_weather.month.unique(),
             albury_weather.groupby("month").Cloud9am.mean())
ax5.set_ylabel("Cloud9am")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # BONUS

# %% [markdown]
# **matplotlib.pyplot.twinx() Function**
#
# The **twinx()** function in pyplot module of matplotlib library is used to make and return a second axes that shares the x-axis.
#
# [Source](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/two_scales.html)

# %%
albury_weather.groupby("month")["Pressure9am"].mean()
# Out:
# month
# 1     1013.793548
# 2     1014.344828
# 3     1017.774194
# 4     1023.136667
# 5     1018.106452
# 6     1019.053333
# 7     1020.419355
# 8     1022.758065
# 9     1015.316667
# 10    1015.967742
# 11    1013.263333
# 12    1012.229032
# Name: Pressure9am, dtype: float64

# %%
albury_weather.groupby("month")["MinTemp"].mean()
# Out:
# month
# 1     17.425806
# 2     16.217241
# 3     15.790323
# 4      9.350000
# 5      8.061290
# 6      5.576667
# 7      5.754839
# 8      4.003226
# 9      7.603333
# 10     7.567742
# 11    10.753333
# 12    14.854839
# Name: MinTemp, dtype: float64

# %%
fig, ax = plt.subplots()

ax.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["MinTemp"].mean())
ax.set_title("Albury")
ax.set_xlabel("Month")
ax.set_ylabel("MinTemp")

ax.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["Pressure9am"].mean())
ax.set_title("Albury")
ax.set_xlabel("Month")
ax.set_ylabel("Pressure9am")

plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,8))

ax[0].plot(albury_weather["month"].unique(), albury_weather.groupby("month")["MinTemp"].mean())
ax[0].set_title("Albury")
ax[0].set_xlabel("Month")
ax[0].set_ylabel("MinTemp")

ax[1].plot(albury_weather["month"].unique(), albury_weather.groupby("month")["Pressure9am"].mean())
ax[1].set_title("Albury")
ax[1].set_xlabel("Month")
ax[1].set_ylabel("Pressure9am")

plt.tight_layout()

# %%
fig, ax = plt.subplots()

ax.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["MinTemp"].mean())
ax.set_title("Albury")
ax.set_xlabel("Month")
ax.set_ylabel("MinTemp")

ax2 = ax.twinx() # The twinx() function is used to make and return a second axes that shares the x-axis.

ax2.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["Pressure9am"].mean())
ax2.set_title("Albury")
ax2.set_xlabel("Month")
ax2.set_ylabel("Pressure9am")

plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["MinTemp"].mean(), color="blue")
ax.set_title("Albury")
ax.set_xlabel("Month")
ax.set_ylabel("MinTemp", color="blue")

ax2 = ax.twinx()

ax2.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["Pressure9am"].mean(), color="red")
ax2.set_title("Albury")
ax2.set_xlabel("Month")
ax2.set_ylabel("Pressure9am", color="red")

plt.show()

# %% [markdown]
# **Axes.tick_params(axis='both', **kwargs)**, change the appearance of ticks, tick labels, and gridlines.
#
# [Source](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.tick_params.html)

# %%
fig, ax = plt.subplots()

ax.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["MinTemp"].mean(), color="blue")
ax.set_title("Albury")
ax.set_xlabel("Month")
ax.set_ylabel("MinTemp", color="blue")
ax.tick_params("y", colors="blue")

ax2 = ax.twinx()

ax2.plot(albury_weather["month"].unique(), albury_weather.groupby("month")["Pressure9am"].mean(), color="red")
ax2.set_title("Albury")
ax2.set_xlabel("Month")
ax2.set_ylabel("Pressure9am", color="red")
ax2.tick_params("y", colors="red")

plt.show()

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
